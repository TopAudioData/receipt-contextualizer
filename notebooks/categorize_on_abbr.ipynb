# %% [markdown]
# # Categorize on abbreviation embeddings with xgboost trained on full name embeddings

# %%
import pickle
from xgboost import XGBClassifier
import pandas as pd
import numpy as np
import ast 

from sklearn.metrics import classification_report

import warnings
warnings.filterwarnings('ignore')

# %%
with open("../models/xbg_model.pkl", "rb") as f:
    model_xgb = pickle.load(f)

# %%
df = pd.read_csv('../data/abbr_embeds_no_context.csv', index_col=0)

# %%
df
# Out:
#      receipt       product_abbr  price
# 0          1  VOLLKORNTORTILLA    2.58  \
# 1          1         TOFU NATUR   4.38
# 2          1    HAUCHSCHN CURRY   3.18
# 3          1   HONEYPOMELO PINK   2.99
# 4          1     DINKEL-CRUNCHY   2.59
# ..       ...                ...    ...
# 138       15    WERNESGR. ALKFR   1.99
# 139       15    WERNESGR. ALKFR  11.40
# 140       15     PFAND 0,08 EUR   0.96
# 141       15      MUELLSACK 60L   3.99
# 142       15        KASTEN LEER   1.50
#
#                                             embeddings
# 0    [-0.04034423828125, -0.005352020263671875, 0.0...
# 1    [-0.0147705078125, -0.0022411346435546875, 0.0...
# 2    [-0.0377197265625, -0.004734039306640625, 0.06...
# 3    [-0.00493621826171875, -0.0181884765625, 0.060...
# 4    [0.01094818115234375, -0.00835418701171875, 0....
# ..                                                 ...
# 138  [-0.0025997161865234375, 0.0118255615234375, 0...
# 139  [-0.0025997161865234375, 0.0118255615234375, 0...
# 140  [-0.00926971435546875, -0.006359100341796875, ...
# 141  [-0.0213165283203125, 0.000835418701171875, 0....
# 142  [-0.04913330078125, 0.050323486328125, 0.04626...
#
# [143 rows x 4 columns]

# %%
df_coded = pd.read_csv('../data/abbr_coded.csv', index_col=0, sep=';')

# %%
df_coded
# Out:
#      prod_id  match                                               name
# 0      15363      1                       Palapa Vollkorntortilla 370g  \
# 1       5603      1                       Berief Bio Tofu Natur 2x200g
# 2       6099      1  Rügenwalder Mühle Hauchschnitt Curry Typ Hähnc...
# 3      13853      1                          Honey Pomelo Pink 1 Stück
# 4       1345      1             REWE Bio Naturland Dinkel Crunchy 500g
# ..       ...    ...                                                ...
# 138    14091      0                             Arko Erdnusstaler 200g
# 139    14091      0                             Arko Erdnusstaler 200g
# 140     8181      9                      Pfanner Eistee Pfirsich 0,33l
# 141    13734      1           ja! Müllsäcke 60l mit Zugbeutel 25 Stück
# 142     6269      9   Wilhelm Brandenburg Kasseler Nacken ohne Knochen
#
#                          category  prod_similarity  price_web
# 0                Süßes & Salziges         0.838345       2.29
# 1                 Fleisch & Fisch         0.855739       2.49
# 2                 Fleisch & Fisch         0.809469       1.59
# 3                   Obst & Gemüse         0.886331       2.99
# 4    Brot, Cerealien & Aufstriche         0.832309       2.59
# ..                            ...              ...        ...
# 138              Süßes & Salziges         0.754391       2.99
# 139              Süßes & Salziges         0.754391       2.99
# 140       Getränke & Genussmittel         0.784003       1.29
# 141              Küche & Haushalt         0.821446       2.49
# 142               Fleisch & Fisch         0.715665       6.22
#
# [143 rows x 6 columns]

# %%
df_abbr_coded = df.join(df_coded)

# %%
df_abbr_coded
# Out:
#      receipt       product_abbr  price
# 0          1  VOLLKORNTORTILLA    2.58  \
# 1          1         TOFU NATUR   4.38
# 2          1    HAUCHSCHN CURRY   3.18
# 3          1   HONEYPOMELO PINK   2.99
# 4          1     DINKEL-CRUNCHY   2.59
# ..       ...                ...    ...
# 138       15    WERNESGR. ALKFR   1.99
# 139       15    WERNESGR. ALKFR  11.40
# 140       15     PFAND 0,08 EUR   0.96
# 141       15      MUELLSACK 60L   3.99
# 142       15        KASTEN LEER   1.50
#
#                                             embeddings  prod_id  match
# 0    [-0.04034423828125, -0.005352020263671875, 0.0...    15363      1  \
# 1    [-0.0147705078125, -0.0022411346435546875, 0.0...     5603      1
# 2    [-0.0377197265625, -0.004734039306640625, 0.06...     6099      1
# 3    [-0.00493621826171875, -0.0181884765625, 0.060...    13853      1
# 4    [0.01094818115234375, -0.00835418701171875, 0....     1345      1
# ..                                                 ...      ...    ...
# 138  [-0.0025997161865234375, 0.0118255615234375, 0...    14091      0
# 139  [-0.0025997161865234375, 0.0118255615234375, 0...    14091      0
# 140  [-0.00926971435546875, -0.006359100341796875, ...     8181      9
# 141  [-0.0213165283203125, 0.000835418701171875, 0....    13734      1
# 142  [-0.04913330078125, 0.050323486328125, 0.04626...     6269      9
#
#                                                   name
# 0                         Palapa Vollkorntortilla 370g  \
# 1                         Berief Bio Tofu Natur 2x200g
# 2    Rügenwalder Mühle Hauchschnitt Curry Typ Hähnc...
# 3                            Honey Pomelo Pink 1 Stück
# 4               REWE Bio Naturland Dinkel Crunchy 500g
# ..                                                 ...
# 138                             Arko Erdnusstaler 200g
# 139                             Arko Erdnusstaler 200g
# 140                      Pfanner Eistee Pfirsich 0,33l
# 141           ja! Müllsäcke 60l mit Zugbeutel 25 Stück
# 142   Wilhelm Brandenburg Kasseler Nacken ohne Knochen
#
#                          category  prod_similarity  price_web
# 0                Süßes & Salziges         0.838345       2.29
# 1                 Fleisch & Fisch         0.855739       2.49
# 2                 Fleisch & Fisch         0.809469       1.59
# 3                   Obst & Gemüse         0.886331       2.99
# 4    Brot, Cerealien & Aufstriche         0.832309       2.59
# ..                            ...              ...        ...
# 138              Süßes & Salziges         0.754391       2.99
# 139              Süßes & Salziges         0.754391       2.99
# 140       Getränke & Genussmittel         0.784003       1.29
# 141              Küche & Haushalt         0.821446       2.49
# 142               Fleisch & Fisch         0.715665       6.22
#
# [143 rows x 10 columns]

# %%
df_filtered = df_abbr_coded[df_abbr_coded.eval('match != 9')]

# %%
df_filtered
# Out:
#      receipt              product_abbr  price
# 0          1         VOLLKORNTORTILLA    2.58  \
# 1          1                TOFU NATUR   4.38
# 2          1           HAUCHSCHN CURRY   3.18
# 3          1          HONEYPOMELO PINK   2.99
# 4          1            DINKEL-CRUNCHY   2.59
# ..       ...                       ...    ...
# 136       15  ZIMTSTERNE DOPPELKEKS GF   4.49
# 137       15          LAYS SALT&VINEG.   2.99
# 138       15           WERNESGR. ALKFR   1.99
# 139       15           WERNESGR. ALKFR  11.40
# 141       15             MUELLSACK 60L   3.99
#
#                                             embeddings  prod_id  match
# 0    [-0.04034423828125, -0.005352020263671875, 0.0...    15363      1  \
# 1    [-0.0147705078125, -0.0022411346435546875, 0.0...     5603      1
# 2    [-0.0377197265625, -0.004734039306640625, 0.06...     6099      1
# 3    [-0.00493621826171875, -0.0181884765625, 0.060...    13853      1
# 4    [0.01094818115234375, -0.00835418701171875, 0....     1345      1
# ..                                                 ...      ...    ...
# 136  [-0.044281005859375, -0.055023193359375, 0.066...    15975      1
# 137  [-0.0172882080078125, 0.0069732666015625, 0.03...    14791      1
# 138  [-0.0025997161865234375, 0.0118255615234375, 0...    14091      0
# 139  [-0.0025997161865234375, 0.0118255615234375, 0...    14091      0
# 141  [-0.0213165283203125, 0.000835418701171875, 0....    13734      1
#
#                                                   name
# 0                         Palapa Vollkorntortilla 370g  \
# 1                         Berief Bio Tofu Natur 2x200g
# 2    Rügenwalder Mühle Hauchschnitt Curry Typ Hähnc...
# 3                            Honey Pomelo Pink 1 Stück
# 4               REWE Bio Naturland Dinkel Crunchy 500g
# ..                                                 ...
# 136                                ja! Doppelkeks 500g
# 137                          Lay's Salt & Vinegar 150g
# 138                             Arko Erdnusstaler 200g
# 139                             Arko Erdnusstaler 200g
# 141           ja! Müllsäcke 60l mit Zugbeutel 25 Stück
#
#                          category  prod_similarity  price_web
# 0                Süßes & Salziges         0.838345       2.29
# 1                 Fleisch & Fisch         0.855739       2.49
# 2                 Fleisch & Fisch         0.809469       1.59
# 3                   Obst & Gemüse         0.886331       2.99
# 4    Brot, Cerealien & Aufstriche         0.832309       2.59
# ..                            ...              ...        ...
# 136              Süßes & Salziges         0.819534       1.69
# 137              Süßes & Salziges         0.893478       1.99
# 138              Süßes & Salziges         0.754391       2.99
# 139              Süßes & Salziges         0.754391       2.99
# 141              Küche & Haushalt         0.821446       2.49
#
# [112 rows x 10 columns]

# %%
cat_list = ['Babybedarf',
    'Brot, Cerealien & Aufstriche',
    'Drogerie & Kosmetik',
    'Fertiggerichte & Konserven',
    'Fleisch & Fisch',
    'Getränke & Genussmittel',
    'Haus & Freizeit',
    'Kaffee, Tee & Kakao',
    'Kochen & Backen',
    'Käse, Eier & Molkerei',
    'Küche & Haushalt',
    'Obst & Gemüse',
    'Süßes & Salziges',
    'Tiefkühlkost',
    'Tierbedarf',
    'Öle, Soßen & Gewürze']
cat_list
# Out:
# ['Babybedarf',
#  'Brot, Cerealien & Aufstriche',
#  'Drogerie & Kosmetik',
#  'Fertiggerichte & Konserven',
#  'Fleisch & Fisch',
#  'Getränke & Genussmittel',
#  'Haus & Freizeit',
#  'Kaffee, Tee & Kakao',
#  'Kochen & Backen',
#  'Käse, Eier & Molkerei',
#  'Küche & Haushalt',
#  'Obst & Gemüse',
#  'Süßes & Salziges',
#  'Tiefkühlkost',
#  'Tierbedarf',
#  'Öle, Soßen & Gewürze']

# %%
cat_dict = dict()

for i, c in enumerate(cat_list):
    cat_dict[c] = i
#df_filtered['category'] = pd.Categorical(df_filtered.category)
#df_filtered['num_category'] = df_filtered.category.cat.codes

# %%
cat_dict
# Out:
# {'Babybedarf': 0,
#  'Brot, Cerealien & Aufstriche': 1,
#  'Drogerie & Kosmetik': 2,
#  'Fertiggerichte & Konserven': 3,
#  'Fleisch & Fisch': 4,
#  'Getränke & Genussmittel': 5,
#  'Haus & Freizeit': 6,
#  'Kaffee, Tee & Kakao': 7,
#  'Kochen & Backen': 8,
#  'Käse, Eier & Molkerei': 9,
#  'Küche & Haushalt': 10,
#  'Obst & Gemüse': 11,
#  'Süßes & Salziges': 12,
#  'Tiefkühlkost': 13,
#  'Tierbedarf': 14,
#  'Öle, Soßen & Gewürze': 15}

# %%
df_filtered['category_num'] = df_filtered.category.map(cat_dict)

# %%
df_filtered
# Out:
#      receipt              product_abbr  price
# 0          1         VOLLKORNTORTILLA    2.58  \
# 1          1                TOFU NATUR   4.38
# 2          1           HAUCHSCHN CURRY   3.18
# 3          1          HONEYPOMELO PINK   2.99
# 4          1            DINKEL-CRUNCHY   2.59
# ..       ...                       ...    ...
# 136       15  ZIMTSTERNE DOPPELKEKS GF   4.49
# 137       15          LAYS SALT&VINEG.   2.99
# 138       15           WERNESGR. ALKFR   1.99
# 139       15           WERNESGR. ALKFR  11.40
# 141       15             MUELLSACK 60L   3.99
#
#                                             embeddings  prod_id  match
# 0    [-0.04034423828125, -0.005352020263671875, 0.0...    15363      1  \
# 1    [-0.0147705078125, -0.0022411346435546875, 0.0...     5603      1
# 2    [-0.0377197265625, -0.004734039306640625, 0.06...     6099      1
# 3    [-0.00493621826171875, -0.0181884765625, 0.060...    13853      1
# 4    [0.01094818115234375, -0.00835418701171875, 0....     1345      1
# ..                                                 ...      ...    ...
# 136  [-0.044281005859375, -0.055023193359375, 0.066...    15975      1
# 137  [-0.0172882080078125, 0.0069732666015625, 0.03...    14791      1
# 138  [-0.0025997161865234375, 0.0118255615234375, 0...    14091      0
# 139  [-0.0025997161865234375, 0.0118255615234375, 0...    14091      0
# 141  [-0.0213165283203125, 0.000835418701171875, 0....    13734      1
#
#                                                   name
# 0                         Palapa Vollkorntortilla 370g  \
# 1                         Berief Bio Tofu Natur 2x200g
# 2    Rügenwalder Mühle Hauchschnitt Curry Typ Hähnc...
# 3                            Honey Pomelo Pink 1 Stück
# 4               REWE Bio Naturland Dinkel Crunchy 500g
# ..                                                 ...
# 136                                ja! Doppelkeks 500g
# 137                          Lay's Salt & Vinegar 150g
# 138                             Arko Erdnusstaler 200g
# 139                             Arko Erdnusstaler 200g
# 141           ja! Müllsäcke 60l mit Zugbeutel 25 Stück
#
#                          category  prod_similarity  price_web  category_num
# 0                Süßes & Salziges         0.838345       2.29            12
# 1                 Fleisch & Fisch         0.855739       2.49             4
# 2                 Fleisch & Fisch         0.809469       1.59             4
# 3                   Obst & Gemüse         0.886331       2.99            11
# 4    Brot, Cerealien & Aufstriche         0.832309       2.59             1
# ..                            ...              ...        ...           ...
# 136              Süßes & Salziges         0.819534       1.69            12
# 137              Süßes & Salziges         0.893478       1.99            12
# 138              Süßes & Salziges         0.754391       2.99            12
# 139              Süßes & Salziges         0.754391       2.99            12
# 141              Küche & Haushalt         0.821446       2.49            10
#
# [112 rows x 11 columns]

# %%
embeddings = df_filtered.embeddings.tolist()
embeddings_list = [ast.literal_eval(s) for s in embeddings]
X = np.array(embeddings_list) 
y_xgb = df_filtered.category_num

# %%
y_pred_xgb = model_xgb.predict(X)

# %%
print(classification_report(y_xgb, y_pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.80      0.75      0.77        16
#            2       0.00      0.00      0.00         0
#            3       0.00      0.00      0.00         6
#            4       0.86      0.40      0.55        15
#            5       0.41      0.69      0.51        13
#            6       0.00      0.00      0.00         4
#            7       0.00      0.00      0.00         1
#            8       0.50      0.29      0.36         7
#            9       0.86      0.55      0.67        11
#           10       0.10      0.67      0.17         3
#           11       1.00      0.20      0.33        25
#           12       0.20      0.12      0.15         8
#           13       0.20      1.00      0.33         1
#           14       0.00      0.00      0.00         1
#           15       0.00      0.00      0.00         1
#
#     accuracy                           0.39       112
#    macro avg       0.33      0.31      0.26       112
# weighted avg       0.63      0.39      0.42       112

# %% [markdown]
# ### Test logistic regression classifier model

# %%
with open("../models/LogReg_model.pkl", "rb") as f:
    model_lr = pickle.load(f)

# %%
y_lr = df_filtered.category

# %%
y_pred_lr = model_lr.predict(X)

# %%
print(classification_report(y_lr, y_pred_lr))
# Out:
#                               precision    recall  f1-score   support
#
# Brot, Cerealien & Aufstriche       0.62      0.94      0.75        16
#          Drogerie & Kosmetik       0.00      0.00      0.00         0
#   Fertiggerichte & Konserven       0.00      0.00      0.00         6
#              Fleisch & Fisch       0.73      0.53      0.62        15
#      Getränke & Genussmittel       0.53      0.77      0.62        13
#              Haus & Freizeit       0.00      0.00      0.00         4
#          Kaffee, Tee & Kakao       0.00      0.00      0.00         1
#              Kochen & Backen       1.00      0.29      0.44         7
#        Käse, Eier & Molkerei       1.00      0.36      0.53        11
#             Küche & Haushalt       0.07      0.67      0.12         3
#                Obst & Gemüse       1.00      0.08      0.15        25
#             Süßes & Salziges       0.67      0.25      0.36         8
#                 Tiefkühlkost       0.33      1.00      0.50         1
#                   Tierbedarf       0.00      0.00      0.00         1
#         Öle, Soßen & Gewürze       0.00      0.00      0.00         1
#
#                     accuracy                           0.41       112
#                    macro avg       0.40      0.33      0.27       112
#                 weighted avg       0.68      0.41      0.41       112
